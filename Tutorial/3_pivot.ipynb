# %%
list1 = [1, 2, 4, 6]

# %%
list1.append(10)

# %%
list1
# Out:
# [1, 2, 4, 6, 10]

# %%
summary = []
summary.append("The columns are miss-matche")
summary.append("The rows are also not in order")

# %%
summary
# Out:
# ['The columns are miss-matche', 'The rows are also not in order']
